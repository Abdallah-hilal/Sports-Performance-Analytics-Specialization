# %% [markdown]
# # English Premier League (EPL) Pythagorean Predictor

# %% [markdown]
# ## Step 1

# %%
# Load the packages

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data. 
# EPL results for the 2017/18 season
path = r"D:\Sports\Assignments\Assignment Data\Week 1\EPL2017-18.xlsx"
EPL18 =  pd.read_excel(path, engine='openpyxl')
print(EPL18.columns.tolist())
# Out:
# ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']

# %%
EPL18.head()
# Out:
#        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR
# 0  20170811         Arsenal     Leicester     4     3   H
# 1  20170812        Brighton      Man City     0     2   A
# 2  20170812         Chelsea       Burnley     2     3   A
# 3  20170812  Crystal Palace  Huddersfield     0     3   A
# 4  20170812         Everton         Stoke     1     0   H

# %%
EPL18.rename(columns={
    'Date': 'Match_Date',
    'HomeTeam': 'Home_Team',
    'AwayTeam': 'Away_Team',
    'FTHG': 'Home_Team_Goals',
    'FTAG': 'Away_Team_Goals',
    'FTR': 'Match_Result'
} , inplace= True)

# %%
EPL18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Match_Date       380 non-null    int64
#  1   Home_Team        380 non-null    object
#  2   Away_Team        380 non-null    object
#  3   Home_Team_Goals  380 non-null    int64
#  4   Away_Team_Goals  380 non-null    int64
#  5   Match_Result     380 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 17.9+ KB

# %%
EPL18.isna().any()
# Out:
# Match_Date         False
# Home_Team          False
# Away_Team          False
# Home_Team_Goals    False
# Away_Team_Goals    False
# Match_Result       False
# dtype: bool

# %% [markdown]
# ## Step 2
# Create a value for a home wins (win= 1, draw=0.5, loss= 0) and away wins and a count variable for each game (=1).

# %%
EPL18['Home_Win'] = EPL18.apply(
    lambda row: 1 if row['Home_Team_Goals'] > row['Away_Team_Goals'] 
   else 0, axis=1
   )

EPL18['Away_Win'] = EPL18.apply(
    lambda row: 1 if row['Away_Team_Goals'] > row['Home_Team_Goals'] else 0, axis=1 
    )

EPL18['Draw'] = EPL18.apply(
    lambda row: 1 if row['Home_Team_Goals'] == row['Away_Team_Goals'] else 0, axis=1
    )
EPL18['Game_Count'] = 1  # each game is counted as 1

# %%
EPL18
# Out:
#      Match_Date       Home_Team     Away_Team  Home_Team_Goals  \
# 0      20170811         Arsenal     Leicester                4
# 1      20170812        Brighton      Man City                0
# 2      20170812         Chelsea       Burnley                2
# 3      20170812  Crystal Palace  Huddersfield                0
# 4      20170812         Everton         Stoke                1
# ..          ...             ...           ...              ...
# 375    20180513       Newcastle       Chelsea                3
# 376    20180513     Southampton      Man City                0
# 377    20180513         Swansea         Stoke                1
# 378    20180513       Tottenham     Leicester                5
# 379    20180513        West Ham       Everton                3
#
#      Away_Team_Goals Match_Result  Home_Win  Away_Win  Draw  Game_Count
# 0                  3            H         1         0     0           1
# 1                  2            A         0         1     0           1
# 2                  3            A         0         1     0           1
# 3                  3            A         0         1     0           1
# 4                  0            H         1         0     0           1
# ..               ...          ...       ...       ...   ...         ...
# 375                0            H         1         0     0           1
# 376                1            A         0         1     0           1
# 377                2            A         0         1     0           1
# 378                4            H         1         0     0           1
# 379                1            H         1         0     0           1
#
# [380 rows x 10 columns]

# %% [markdown]
# ## Step 3
# Create a file for games played in 2017 (before date 20180000) and another one for games played in 2018 (after date 20180000).

# %%
EPL_2017 = EPL18[EPL18['Match_Date'] < 20180000]

# Games played in 2018 (i.e., after 20180000)
EPL_2018 = EPL18[EPL18['Match_Date'] >= 20180000]

# %%
EPL_2018
# Out:
#      Match_Date    Home_Team     Away_Team  Home_Team_Goals  Away_Team_Goals  \
# 209    20180101     Brighton   Bournemouth                2                2
# 210    20180101      Burnley     Liverpool                1                2
# 211    20180101      Everton    Man United                0                2
# 212    20180101    Leicester  Huddersfield                3                0
# 213    20180101        Stoke     Newcastle                0                1
# ..          ...          ...           ...              ...              ...
# 375    20180513    Newcastle       Chelsea                3                0
# 376    20180513  Southampton      Man City                0                1
# 377    20180513      Swansea         Stoke                1                2
# 378    20180513    Tottenham     Leicester                5                4
# 379    20180513     West Ham       Everton                3                1
#
#     Match_Result  Home_Win  Away_Win  Draw  Game_Count
# 209            D         0         0     1           1
# 210            A         0         1     0           1
# 211            A         0         1     0           1
# 212            H         1         0     0           1
# 213            A         0         1     0           1
# ..           ...       ...       ...   ...         ...
# 375            H         1         0     0           1
# 376            A         0         1     0           1
# 377            A         0         1     0           1
# 378            H         1         0     0           1
# 379            H         1         0     0           1
#
# [171 rows x 10 columns]

# %% [markdown]
# ## Step 4 (home team)
# For the 2017 games, use .groupby to create a dataframe aggregating by home team the variables for count, home wins, goals for and goals against.

# %%
home_stats = EPL_2017.groupby('Home_Team')[['Game_Count', 'Home_Win','Home_Team_Goals','Away_Team_Goals']].sum().reset_index()

# %%
home_stats18 = EPL_2018.groupby('Home_Team')[['Game_Count', 'Home_Win','Home_Team_Goals','Away_Team_Goals']].sum().reset_index()

# %%
home_stats.rename(columns= { 
                             'Home_Win': 'Home_Wins',
                             'Home_Team_Goals': 'Goals_for',
                             'Away_Team_Goals' : 'Goals_against'} , inplace= True)

# %%
home_stats18.rename(columns= { 
                             'Home_Win': 'Home_Wins',
                             'Home_Team_Goals': 'Goals_for',
                             'Away_Team_Goals' : 'Goals_against'} , inplace= True)

# %%
home_stats
# Out:
#          Home_Team  Game_Count  Home_Wins  Goals_for  Goals_against
# 0          Arsenal          10          8         25             10
# 1      Bournemouth          11          3         14             17
# 2         Brighton          10          3         10             12
# 3          Burnley          10          5          7              6
# 4          Chelsea          11          8         21              7
# 5   Crystal Palace          11          3         14             18
# 6          Everton          10          6         17             13
# 7     Huddersfield          11          4         10             12
# 8        Leicester          10          4         13             14
# 9        Liverpool          11          6         21              4
# 10        Man City          10          9         36              7
# 11      Man United          11          8         24              5
# 12       Newcastle          11          3          9             13
# 13     Southampton          11          3         13             15
# 14           Stoke          10          4         13             19
# 15         Swansea          10          2          6             15
# 16       Tottenham          10          6         21              8
# 17         Watford          11          3         14             23
# 18       West Brom          11          1         10             15
# 19        West Ham           9          3         10             14

# %%
home_stats18
# Out:
#          Home_Team  Game_Count  Home_Wins  Goals_for  Goals_against
# 0          Arsenal           9          7         29             10
# 1      Bournemouth           8          4         12             13
# 2         Brighton           9          4         14             13
# 3          Burnley           9          2          9             11
# 4          Chelsea           8          3          9              9
# 5   Crystal Palace           8          4         15              9
# 6          Everton           9          4         11              9
# 7     Huddersfield           8          2          6             13
# 8        Leicester           9          3         12              8
# 9        Liverpool           8          6         24              6
# 10        Man City           9          7         25              7
# 11      Man United           8          7         14              4
# 12       Newcastle           8          5         12              4
# 13     Southampton           8          1          7             11
# 14           Stoke           9          1          7             11
# 15         Swansea           9          4         11              9
# 16       Tottenham           9          7         19              8
# 17         Watford           8          4         13              8
# 18       West Brom           8          2         11             14
# 19        West Ham          10          4         14             12

# %% [markdown]
# ## Step 5 (home team)
# Then, use .groupby to  create a separate dataframe aggregating by away team the variables for count, away wins, goals for and goals against.

# %%
away_stats = EPL_2017.groupby('Away_Team')[['Game_Count', 'Away_Win','Away_Team_Goals', 'Home_Team_Goals']].sum().reset_index()


# Rename columns for better clarity
away_stats = away_stats.rename(columns={
    'Away_Team': 'Away_Team_Name',
    'Away_Win': 'Away_Wins',
    'Home_Team_Goals': 'Goals_against',
    'Away_Team_Goals': 'Goals_for'
    
})

# Display the result
away_stats
# Out:
#     Away_Team_Name  Game_Count  Away_Wins  Goals_for  Goals_against
# 0          Arsenal          11          3         13             16
# 1      Bournemouth          10          2          6             15
# 2         Brighton          11          2          5             13
# 3          Burnley          11          4         11             11
# 4          Chelsea          10          6         18              7
# 5   Crystal Palace          10          1          4             14
# 6          Everton          11          1          8             19
# 7     Huddersfield          10          2          8             20
# 8        Leicester          11          3         18             18
# 9        Liverpool          10          5         27             20
# 10        Man City          11         10         25              5
# 11      Man United          10          5         19             11
# 12       Newcastle          10          2         10             17
# 13     Southampton          10          1          7             15
# 14           Stoke          11          1         10             27
# 15         Swansea          11          2          7             17
# 16       Tottenham          10          5         18             12
# 17         Watford          10          4         16             14
# 18       West Brom          10          1          5             13
# 19        West Ham          11          1         12             24

# %%
away_stats18 = EPL_2018.groupby('Away_Team')[['Game_Count', 'Away_Win','Away_Team_Goals', 'Home_Team_Goals']].sum().reset_index()


# Rename columns for better clarity
away_stats18 = away_stats18.rename(columns={
    'Away_Team': 'Away_Team_Name',
    'Away_Win': 'Away_Wins',
    'Home_Team_Goals': 'Goals_against',
    'Away_Team_Goals': 'Goals_for'
    
})

# Display the result
away_stats18
# Out:
#     Away_Team_Name  Game_Count  Away_Wins  Goals_for  Goals_against
# 0          Arsenal           8          1          7             15
# 1      Bournemouth           9          2         13             16
# 2         Brighton           8          0          5             16
# 3          Burnley           8          3          9             11
# 4          Chelsea           9          4         14             15
# 5   Crystal Palace           9          3         12             14
# 6          Everton           8          2          8             17
# 7     Huddersfield           9          1          4             13
# 8        Leicester           8          2         13             20
# 9        Liverpool           9          4         12              8
# 10        Man City           8          6         20              8
# 11      Man United           9          5         11              8
# 12       Newcastle           9          2          8             13
# 13     Southampton           9          2         10             15
# 14           Stoke           8          1          5             11
# 15         Swansea           8          0          4             15
# 16       Tottenham           9          5         16              8
# 17         Watford           9          0          1             19
# 18       West Brom           9          2          5             14
# 19        West Ham           8          2         12             18

# %% [markdown]
# ## Step 6 (home team)

# %%
away_stats = away_stats.rename(columns={
    "Game_Count": 'Away_Game_Count',
    'Away_Team_Name': 'Away_Team_Name',
    'Away_Wins': 'Away_Wins',
    'Goals_against': 'Away_Goals_Conceded',
    'Goals_for': 'Away_Goals_Scored'
})

home_stats.rename(columns={
    "Game_Count": "Home_Game_Count",
    'Home_Wins': 'Home_Wins',
    'Goals_for': 'Home_Goals_Scored',
    'Goals_against': 'Home_Goals_Conceded'
}, inplace=True)

# %%
away_stats18 = away_stats18.rename(columns={
    "Game_Count": 'Away_Game_Count',
    'Away_Team_Name': 'Away_Team_Name',
    'Away_Wins': 'Away_Wins',
    'Goals_against': 'Away_Goals_Conceded',
    'Goals_for': 'Away_Goals_Scored'
})

home_stats18.rename(columns={
    "Game_Count": "Home_Game_Count",
    'Home_Wins': 'Home_Wins',
    'Goals_for': 'Home_Goals_Scored',
    'Goals_against': 'Home_Goals_Conceded'
}, inplace=True)

# %%
home_stats.head()
# Out:
#      Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal               10          8                 25
# 1  Bournemouth               11          3                 14
# 2     Brighton               10          3                 10
# 3      Burnley               10          5                  7
# 4      Chelsea               11          8                 21
#
#    Home_Goals_Conceded
# 0                   10
# 1                   17
# 2                   12
# 3                    6
# 4                    7

# %%
home_stats18.head()
# Out:
#      Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal                9          7                 29
# 1  Bournemouth                8          4                 12
# 2     Brighton                9          4                 14
# 3      Burnley                9          2                  9
# 4      Chelsea                8          3                  9
#
#    Home_Goals_Conceded
# 0                   10
# 1                   13
# 2                   13
# 3                   11
# 4                    9

# %%
# Merging the home and away stats dataframes on the team column
full_stats17 = pd.merge(home_stats, away_stats,  left_on="Home_Team", right_on="Away_Team_Name")

full_stats17.head()
# Out:
#      Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal               10          8                 25
# 1  Bournemouth               11          3                 14
# 2     Brighton               10          3                 10
# 3      Burnley               10          5                  7
# 4      Chelsea               11          8                 21
#
#    Home_Goals_Conceded Away_Team_Name  Away_Game_Count  Away_Wins  \
# 0                   10        Arsenal               11          3
# 1                   17    Bournemouth               10          2
# 2                   12       Brighton               11          2
# 3                    6        Burnley               11          4
# 4                    7        Chelsea               10          6
#
#    Away_Goals_Scored  Away_Goals_Conceded
# 0                 13                   16
# 1                  6                   15
# 2                  5                   13
# 3                 11                   11
# 4                 18                    7

# %%
# Merging the home and away stats dataframes on the team column
full_stats18 = pd.merge(home_stats18, away_stats18,  left_on="Home_Team", right_on="Away_Team_Name")

full_stats18.head()
# Out:
#      Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal                9          7                 29
# 1  Bournemouth                8          4                 12
# 2     Brighton                9          4                 14
# 3      Burnley                9          2                  9
# 4      Chelsea                8          3                  9
#
#    Home_Goals_Conceded Away_Team_Name  Away_Game_Count  Away_Wins  \
# 0                   10        Arsenal                8          1
# 1                   13    Bournemouth                9          2
# 2                   13       Brighton                8          0
# 3                   11        Burnley                8          3
# 4                    9        Chelsea                9          4
#
#    Away_Goals_Scored  Away_Goals_Conceded
# 0                  7                   15
# 1                 13                   16
# 2                  5                   16
# 3                  9                   11
# 4                 14                   15

# %%
full_stats18
# Out:
#          Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0          Arsenal                9          7                 29
# 1      Bournemouth                8          4                 12
# 2         Brighton                9          4                 14
# 3          Burnley                9          2                  9
# 4          Chelsea                8          3                  9
# 5   Crystal Palace                8          4                 15
# 6          Everton                9          4                 11
# 7     Huddersfield                8          2                  6
# 8        Leicester                9          3                 12
# 9        Liverpool                8          6                 24
# 10        Man City                9          7                 25
# 11      Man United                8          7                 14
# 12       Newcastle                8          5                 12
# 13     Southampton                8          1                  7
# 14           Stoke                9          1                  7
# 15         Swansea                9          4                 11
# 16       Tottenham                9          7                 19
# 17         Watford                8          4                 13
# 18       West Brom                8          2                 11
# 19        West Ham               10          4                 14
#
#     Home_Goals_Conceded  Away_Team_Name  Away_Game_Count  Away_Wins  \
# 0                    10         Arsenal                8          1
# 1                    13     Bournemouth                9          2
# 2                    13        Brighton                8          0
# 3                    11         Burnley                8          3
# 4                     9         Chelsea                9          4
# 5                     9  Crystal Palace                9          3
# 6                     9         Everton                8          2
# 7                    13    Huddersfield                9          1
# 8                     8       Leicester                8          2
# 9                     6       Liverpool                9          4
# 10                    7        Man City                8          6
# 11                    4      Man United                9          5
# 12                    4       Newcastle                9          2
# 13                   11     Southampton                9          2
# 14                   11           Stoke                8          1
# 15                    9         Swansea                8          0
# 16                    8       Tottenham                9          5
# 17                    8         Watford                9          0
# 18                   14       West Brom                9          2
# 19                   12        West Ham                8          2
#
#     Away_Goals_Scored  Away_Goals_Conceded
# 0                   7                   15
# 1                  13                   16
# 2                   5                   16
# 3                   9                   11
# 4                  14                   15
# 5                  12                   14
# 6                   8                   17
# 7                   4                   13
# 8                  13                   20
# 9                  12                    8
# 10                 20                    8
# 11                 11                    8
# 12                  8                   13
# 13                 10                   15
# 14                  5                   11
# 15                  4                   15
# 16                 16                    8
# 17                  1                   19
# 18                  5                   14
# 19                 12                   18

# %%
#full_stats_2017_2018 = pd.merge(full_stats17, full_stats18, on="Home_Team",suffixes=['_2017', '_2018'])

# %%
#full_stats_2017_2018

# %% [markdown]
# ## Optional steps, not required for Assessment
# ### (Uncomment to run)

# %%
# Plot the data

#sns.relplot(x="pyth17", y="wpc17", data =EPL17)

# %%
# Run the regression

#pyth_lm = smf.ols(formula = 'wpc17 ~ pyth17', data=EPL17).fit()
#pyth_lm.summary()

# %% [markdown]
# ## Step 7 (=Step 4 (away team))

# %% [markdown]
# ## Step 7 (=Step 5 (away team))

# %% [markdown]
# ## Step 7 (=Step 6 (away team))

# %% [markdown]
# ## Optional steps, not required for Assessment
# ### (Uncomment to run)

# %%
# Plot the data

#sns.relplot(x="pyth18", y="wpc18", data =EPL2018)

# %%
# Run the regression

#pyth_lm = smf.ols(formula = 'wpc18 ~ pyth18', data=EPL2018).fit()
#pyth_lm.summary()

# %%
full_stats17.head()
# Out:
#      Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal               10          8                 25
# 1  Bournemouth               11          3                 14
# 2     Brighton               10          3                 10
# 3      Burnley               10          5                  7
# 4      Chelsea               11          8                 21
#
#    Home_Goals_Conceded Away_Team_Name  Away_Game_Count  Away_Wins  \
# 0                   10        Arsenal               11          3
# 1                   17    Bournemouth               10          2
# 2                   12       Brighton               11          2
# 3                    6        Burnley               11          4
# 4                    7        Chelsea               10          6
#
#    Away_Goals_Scored  Away_Goals_Conceded
# 0                 13                   16
# 1                  6                   15
# 2                  5                   13
# 3                 11                   11
# 4                 18                    7

# %% [markdown]
# ## Step 8

# %%
full_stats17['Total_Wins'] = full_stats17['Home_Wins'] + full_stats17['Away_Wins']
full_stats17['Total_Games'] = full_stats17['Home_Game_Count'] + full_stats17['Away_Game_Count']
full_stats17['Total_Goals_For'] = full_stats17['Home_Goals_Scored'] + full_stats17['Away_Goals_Scored']
full_stats17['Total_Goals_Against'] = full_stats17['Home_Goals_Conceded'] + full_stats17['Away_Goals_Conceded']

# %%
full_stats18['Total_Wins'] = full_stats18['Home_Wins'] + full_stats18['Away_Wins']
full_stats18['Total_Games'] = full_stats18['Home_Game_Count'] + full_stats18['Away_Game_Count']
full_stats18['Total_Goals_For'] = full_stats18['Home_Goals_Scored'] + full_stats18['Away_Goals_Scored']
full_stats18['Total_Goals_Against'] = full_stats18['Home_Goals_Conceded'] + full_stats18['Away_Goals_Conceded']

# %%
full_stats18
# Out:
#          Home_Team  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0          Arsenal                9          7                 29
# 1      Bournemouth                8          4                 12
# 2         Brighton                9          4                 14
# 3          Burnley                9          2                  9
# 4          Chelsea                8          3                  9
# 5   Crystal Palace                8          4                 15
# 6          Everton                9          4                 11
# 7     Huddersfield                8          2                  6
# 8        Leicester                9          3                 12
# 9        Liverpool                8          6                 24
# 10        Man City                9          7                 25
# 11      Man United                8          7                 14
# 12       Newcastle                8          5                 12
# 13     Southampton                8          1                  7
# 14           Stoke                9          1                  7
# 15         Swansea                9          4                 11
# 16       Tottenham                9          7                 19
# 17         Watford                8          4                 13
# 18       West Brom                8          2                 11
# 19        West Ham               10          4                 14
#
#     Home_Goals_Conceded  Away_Team_Name  Away_Game_Count  Away_Wins  \
# 0                    10         Arsenal                8          1
# 1                    13     Bournemouth                9          2
# 2                    13        Brighton                8          0
# 3                    11         Burnley                8          3
# 4                     9         Chelsea                9          4
# 5                     9  Crystal Palace                9          3
# 6                     9         Everton                8          2
# 7                    13    Huddersfield                9          1
# 8                     8       Leicester                8          2
# 9                     6       Liverpool                9          4
# 10                    7        Man City                8          6
# 11                    4      Man United                9          5
# 12                    4       Newcastle                9          2
# 13                   11     Southampton                9          2
# 14                   11           Stoke                8          1
# 15                    9         Swansea                8          0
# 16                    8       Tottenham                9          5
# 17                    8         Watford                9          0
# 18                   14       West Brom                9          2
# 19                   12        West Ham                8          2
#
#     Away_Goals_Scored  Away_Goals_Conceded  Total_Wins  Total_Games  \
# 0                   7                   15           8           17
# 1                  13                   16           6           17
# 2                   5                   16           4           17
# 3                   9                   11           5           17
# 4                  14                   15           7           17
# 5                  12                   14           7           17
# 6                   8                   17           6           17
# 7                   4                   13           3           17
# 8                  13                   20           5           17
# 9                  12                    8          10           17
# 10                 20                    8          13           17
# 11                 11                    8          12           17
# 12                  8                   13           7           17
# 13                 10                   15           3           17
# 14                  5                   11           2           17
# 15                  4                   15           4           17
# 16                 16                    8          12           18
# 17                  1                   19           4           17
# 18                  5                   14           4           17
# 19                 12                   18           6           18
#
#     Total_Goals_For  Total_Goals_Against
# 0                36                   25
# 1                25                   29
# 2                19                   29
# 3                18                   22
# 4                23                   24
# 5                27                   23
# 6                19                   26
# 7                10                   26
# 8                25                   28
# 9                36                   14
# 10               45                   15
# 11               25                   12
# 12               20                   17
# 13               17                   26
# 14               12                   22
# 15               15                   24
# 16               35                   16
# 17               14                   27
# 18               16                   28
# 19               26                   30

# %%
full_stats17['wpc'] = full_stats17['Total_Wins'] / full_stats17['Total_Games']

full_stats17['pyth'] = (full_stats17['Total_Goals_For']**2) / (full_stats17['Total_Goals_For']**2 + full_stats17['Total_Goals_Against']**2)

# %%
full_stats18['wpc'] = full_stats18['Total_Wins'] / full_stats18['Total_Games']

full_stats18['pyth'] = (full_stats18['Total_Goals_For']**2) / (full_stats18['Total_Goals_For']**2 + full_stats18['Total_Goals_Against']**2)

# %%
full_stats17.drop("Away_Team_Name" , inplace = True , axis = 1)
full_stats17.rename(columns= {"Home_Team": "Team_Name"}, inplace= True )

# %%
full_stats18.drop("Away_Team_Name" , inplace = True , axis = 1)
full_stats18.rename(columns= {"Home_Team": "Team_Name"}, inplace= True )

# %%
full_stats17.head()
# Out:
#      Team_Name  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal               10          8                 25
# 1  Bournemouth               11          3                 14
# 2     Brighton               10          3                 10
# 3      Burnley               10          5                  7
# 4      Chelsea               11          8                 21
#
#    Home_Goals_Conceded  Away_Game_Count  Away_Wins  Away_Goals_Scored  \
# 0                   10               11          3                 13
# 1                   17               10          2                  6
# 2                   12               11          2                  5
# 3                    6               11          4                 11
# 4                    7               10          6                 18
#
#    Away_Goals_Conceded  Total_Wins  Total_Games  Total_Goals_For  \
# 0                   16          11           21               38
# 1                   15           5           21               20
# 2                   13           5           21               15
# 3                   11           9           21               18
# 4                    7          14           21               39
#
#    Total_Goals_Against       wpc      pyth
# 0                   26  0.523810  0.681132
# 1                   32  0.238095  0.280899
# 2                   25  0.238095  0.264706
# 3                   17  0.428571  0.528548
# 4                   14  0.666667  0.885847

# %%
full_stats18.head()
# Out:
#      Team_Name  Home_Game_Count  Home_Wins  Home_Goals_Scored  \
# 0      Arsenal                9          7                 29
# 1  Bournemouth                8          4                 12
# 2     Brighton                9          4                 14
# 3      Burnley                9          2                  9
# 4      Chelsea                8          3                  9
#
#    Home_Goals_Conceded  Away_Game_Count  Away_Wins  Away_Goals_Scored  \
# 0                   10                8          1                  7
# 1                   13                9          2                 13
# 2                   13                8          0                  5
# 3                   11                8          3                  9
# 4                    9                9          4                 14
#
#    Away_Goals_Conceded  Total_Wins  Total_Games  Total_Goals_For  \
# 0                   15           8           17               36
# 1                   16           6           17               25
# 2                   16           4           17               19
# 3                   11           5           17               18
# 4                   15           7           17               23
#
#    Total_Goals_Against       wpc      pyth
# 0                   25  0.470588  0.674649
# 1                   29  0.352941  0.426330
# 2                   29  0.235294  0.300333
# 3                   22  0.294118  0.400990
# 4                   24  0.411765  0.478733

# %% [markdown]
# ## Step 9

# %% [markdown]
# ## Optional steps, not required for Assessment
# ### (Uncomment to run)

# %%
#sns.relplot(x="pyth17", y="wpc18", data =Half2predictor)

# %%
#sns.relplot(x="wpc17", y="wpc18", data =Half2predictor)
